# %%
import feedparser
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import nltk

# 首次使用前需要下载VADER词典
# nltk.download('vader_lexicon')

# RSS链接
rss_url = "https://cointelegraph.com/rss"

# 解析RSS Feed
feed = feedparser.parse(rss_url)

# 初始化VADER情感分析器
sid = SentimentIntensityAnalyzer()

# 对每个feed的标题进行情感分析
for entry in feed.entries:
    title = entry.title
    sentiment_score = sid.polarity_scores(title)
    print(f"标题: {title}")
    print(f"情感分数: {sentiment_score}\n")
# Out:
# 标题: Binance to launch Thai exchange in joint venture with local energy giant
# 情感分数: {'neg': 0.0, 'neu': 0.84, 'pos': 0.16, 'compound': 0.2732}
#
# 标题: Solana hoses down ‘inaccurate’ CertiK report on Saga phone security flaws
# 情感分数: {'neg': 0.0, 'neu': 0.806, 'pos': 0.194, 'compound': 0.34}
#
# 标题: New York finance regulator tightens crypto listing guidance
# 情感分数: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 标题: Paxos to issue USD stablecoin in Singapore, wins initial approval
# 情感分数: {'neg': 0.0, 'neu': 0.541, 'pos': 0.459, 'compound': 0.7783}
#
# 标题: Solana jumps 20% as Cathie Wood lauds its speed and cost over Ethereum
# 情感分数: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 标题: Grayscale ETH futures ETF a ‘trojan horse’ for spot Ethereum ETF: Analyst
# 情感分数: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 标题: Expect some crypto companies to fail in the wake of Bitcoin's halving
# 情感分数: {'neg': 0.241, 'neu': 0.759, 'pos': 0.0, 'compound': -0.5423}
#
# 标题: Solana (SOL), Avalanche (AVAX) and dYdX produce double-digit gains as Bitcoin reclaims $37K
# 情感分数: {'neg': 0.0, 'neu': 0.833, 'pos': 0.167, 'compound': 0.34}
#
# 标题: US House Financial Services subcommittee looks for answers on crypto and crime
# 情感分数: {'neg': 0.241, 'neu': 0.759, 'pos': 0.0, 'compound': -0.5423}
#
# 标题: Why is Bitcoin price up today?
# 情感分数: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 标题: Disney launches NFT platform, eye issues at ApeFest and NFT sales rise: Nifty Newsletter
# 情感分数: {'neg': 0.0, 'neu': 0.828, 'pos': 0.172, 'compound': 0.4019}
#
# 标题: Here’s what happened in crypto today
# 情感分数: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 标题: 46% of crypto lost from exploits is due to traditional Web2 flaws — Immunefi
# 情感分数: {'neg': 0.299, 'neu': 0.701, 'pos': 0.0, 'compound': -0.5719}
#
# 标题: Price analysis 11/15: BTC, ETH, BNB, XRP, SOL, ADA, DOGE, MATIC, LINK, TON
# 情感分数: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 标题: Bakkt shifts focus to custody services, adds support for DOGE, SHIB, other coins
# 情感分数: {'neg': 0.0, 'neu': 0.816, 'pos': 0.184, 'compound': 0.4019}
#
# 标题: Layer 2 networks hit $13B TVL, but challenges still remain
# 情感分数: {'neg': 0.0, 'neu': 0.847, 'pos': 0.153, 'compound': 0.1154}
#
# 标题: Breaking into Liberland: Dodging guards with inner-tubes, decoys and diplomats
# 情感分数: {'neg': 0.135, 'neu': 0.865, 'pos': 0.0, 'compound': -0.1027}
#
# 标题: New York MoMA now has tokenized artworks in its permanent collection
# 情感分数: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 标题: Microsoft, Tencent and other tech giants join Decentralized Infura Network
# 情感分数: {'neg': 0.0, 'neu': 0.804, 'pos': 0.196, 'compound': 0.296}
#
# 标题: OpenAI halts new ChatGPT Plus sign-ups amid high demand
# 情感分数: {'neg': 0.158, 'neu': 0.842, 'pos': 0.0, 'compound': -0.128}
#
# 标题: 3 reasons why Bitcoin price failed to break $37K
# 情感分数: {'neg': 0.32, 'neu': 0.68, 'pos': 0.0, 'compound': -0.5106}
#
# 标题: Web3 advocate and author Alex Tapscott on the future of blockchain mass adoption
# 情感分数: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 标题: Commerzbank granted crypto custody license in Germany
# 情感分数: {'neg': 0.0, 'neu': 0.75, 'pos': 0.25, 'compound': 0.25}
#
# 标题: Financial decision-making: Using smart-analytics
# 情感分数: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 标题: Robinhood meme stock punters denied class suit certification
# 情感分数: {'neg': 0.293, 'neu': 0.707, 'pos': 0.0, 'compound': -0.4404}
#
# 标题: Binance Labs invests in ARKM, the native token of Arkham platform
# 情感分数: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 标题: Kazakhstan officially launches digital tenge
# 情感分数: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 标题: Poloniex crypto exchange resumes withdrawals after $100M hack
# 情感分数: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 标题: Why is the crypto market down today?
# 情感分数: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 标题: Singapore introduces 5 new pilots to test asset tokenization
# 情感分数: {'neg': 0.0, 'neu': 0.737, 'pos': 0.263, 'compound': 0.3612}
